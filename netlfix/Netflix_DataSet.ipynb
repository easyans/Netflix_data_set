# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\AAkash\Desktop\netlfix\Best Movie by Year Netflix.csv")

# %%
data
# Out:
#     index                                           TITLE  RELEASE_YEAR  \
# 0       0                                 White Christmas          1954
# 1       1                            The Guns of Navarone          1961
# 2       2                                    My Fair Lady          1964
# 3       3                                Bonnie and Clyde          1967
# 4       4                                     Dirty Harry          1971
# 5       5                                    The Exorcist          1973
# 6       6                 Monty Python and the Holy Grail          1975
# 7       7                                     Taxi Driver          1976
# 8       8                                   Life of Brian          1979
# 9       9                                 The Blue Lagoon          1980
# 10     10                                           Annie          1982
# 11     11                                       Christine          1983
# ...

# %%
data.count()
# Out:
# index              49
# TITLE              49
# RELEASE_YEAR       49
# SCORE              49
# MAIN_GENRE         49
# MAIN_PRODUCTION    49
# dtype: int64

# %%
data.isnull()
# Out:
#     index  TITLE  RELEASE_YEAR  SCORE  MAIN_GENRE  MAIN_PRODUCTION
# 0   False  False         False  False       False            False
# 1   False  False         False  False       False            False
# 2   False  False         False  False       False            False
# 3   False  False         False  False       False            False
# 4   False  False         False  False       False            False
# 5   False  False         False  False       False            False
# 6   False  False         False  False       False            False
# 7   False  False         False  False       False            False
# 8   False  False         False  False       False            False
# 9   False  False         False  False       False            False
# 10  False  False         False  False       False            False
# 11  False  False         False  False       False            False
# 12  False  False         False  False       False            False
# ...

# %%
data.isnull().sum()
# Out:
# index              0
# TITLE              0
# RELEASE_YEAR       0
# SCORE              0
# MAIN_GENRE         0
# MAIN_PRODUCTION    0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
data.head(2)
# Out:
#    index                 TITLE  RELEASE_YEAR  SCORE MAIN_GENRE MAIN_PRODUCTION
# 0      0       White Christmas          1954    7.5    romance              US
# 1      1  The Guns of Navarone          1961    7.5        war              US

# %%
data.groupby('RELEASE_YEAR').sum()
# Out:
#               index  SCORE
# RELEASE_YEAR
# 1954              0    7.5
# 1961              1    7.5
# 1964              2    7.8
# 1967              3    7.7
# 1971              4    7.7
# 1973              5    8.1
# 1975              6    8.2
# 1976              7    8.3
# 1979              8    8.0
# 1980              9    5.8
# 1982             10    6.6
# 1983             11    6.7
# 1984             12    8.3
# 1986             13    8.1
# 1987             14    8.3
# 1989             15    7.7
# 1990             16    7.8
# 1991             17    6.9
# 1992             18    7.2
# 1993             19    7.5
# 1994             20    8.8
# 1995             21    7.1
# 1996             22    7.0
# 1997             23    8.0
# 1998             24    8.6
# 1999             25    7.3
# 2000             26    7.2
# 2001             27    8.1
# 2002             28    7.7
# 2003             29    8.0
# 2004             30    8.1
# 2005             31    7.3
# ...

# %%
data.groupby('RELEASE_YEAR').sum().head(20)
# Out:
#               index  SCORE
# RELEASE_YEAR
# 1954              0    7.5
# 1961              1    7.5
# 1964              2    7.8
# 1967              3    7.7
# 1971              4    7.7
# 1973              5    8.1
# 1975              6    8.2
# 1976              7    8.3
# 1979              8    8.0
# 1980              9    5.8
# 1982             10    6.6
# 1983             11    6.7
# 1984             12    8.3
# 1986             13    8.1
# 1987             14    8.3
# 1989             15    7.7
# 1990             16    7.8
# 1991             17    6.9
# 1992             18    7.2
# 1993             19    7.5

# %%
data.groupby('RELEASE_YEAR')['SCORE'].sum().sort_values(ascending= False)
# Out:
# RELEASE_YEAR
# 2020    9.0
# 1994    8.8
# 2010    8.8
# 2021    8.7
# 1998    8.6
# 2016    8.4
# 2012    8.4
# 2009    8.4
# 2019    8.4
# 2007    8.3
# 1987    8.3
# 1976    8.3
# 1984    8.3
# 2015    8.2
# 2014    8.2
# 2011    8.2
# 2017    8.2
# 2018    8.2
# 1975    8.2
# 2004    8.1
# 1986    8.1
# 2013    8.1
# 1973    8.1
# 2001    8.1
# 2006    8.1
# 2008    8.0
# 1979    8.0
# 1997    8.0
# 2003    8.0
# 1964    7.8
# 1990    7.8
# 1967    7.7
# 2002    7.7
# 1989    7.7
# 1971    7.7
# 1954    7.5
# 1961    7.5
# 1993    7.5
# 2005    7.3
# 1999    7.3
# 2000    7.2
# 1992    7.2
# 2022    7.2
# 1995    7.1
# 1996    7.0
# 1991    6.9
# 1983    6.7
# 1982    6.6
# 1980    5.8
# Name: SCORE, dtype: float64

# %%
data.head(2)
# Out:
#    index                 TITLE  RELEASE_YEAR  SCORE MAIN_GENRE MAIN_PRODUCTION
# 0      0       White Christmas          1954    7.5    romance              US
# 1      1  The Guns of Navarone          1961    7.5        war              US

# %%
data[data.SCORE < 10]
# Out:
#     index                                           TITLE  RELEASE_YEAR  \
# 0       0                                 White Christmas          1954
# 1       1                            The Guns of Navarone          1961
# 2       2                                    My Fair Lady          1964
# 3       3                                Bonnie and Clyde          1967
# 4       4                                     Dirty Harry          1971
# 5       5                                    The Exorcist          1973
# 6       6                 Monty Python and the Holy Grail          1975
# 7       7                                     Taxi Driver          1976
# 8       8                                   Life of Brian          1979
# 9       9                                 The Blue Lagoon          1980
# 10     10                                           Annie          1982
# 11     11                                       Christine          1983
# ...

# %%
data
# Out:
#     index                                           TITLE  RELEASE_YEAR  \
# 0       0                                 White Christmas          1954
# 1       1                            The Guns of Navarone          1961
# 2       2                                    My Fair Lady          1964
# 3       3                                Bonnie and Clyde          1967
# 4       4                                     Dirty Harry          1971
# 5       5                                    The Exorcist          1973
# 6       6                 Monty Python and the Holy Grail          1975
# 7       7                                     Taxi Driver          1976
# 8       8                                   Life of Brian          1979
# 9       9                                 The Blue Lagoon          1980
# 10     10                                           Annie          1982
# 11     11                                       Christine          1983
# ...

# %%
data.head(20)
# Out:
#     index                            TITLE  RELEASE_YEAR  SCORE MAIN_GENRE  \
# 0       0                  White Christmas          1954    7.5    romance
# 1       1             The Guns of Navarone          1961    7.5        war
# 2       2                     My Fair Lady          1964    7.8      drama
# 3       3                 Bonnie and Clyde          1967    7.7      drama
# 4       4                      Dirty Harry          1971    7.7   thriller
# 5       5                     The Exorcist          1973    8.1     horror
# 6       6  Monty Python and the Holy Grail          1975    8.2     comedy
# 7       7                      Taxi Driver          1976    8.3      crime
# 8       8                    Life of Brian          1979    8.0     comedy
# 9       9                  The Blue Lagoon          1980    5.8    romance
# 10     10                            Annie          1982    6.6      drama
# ...

# %%
data.groupby('TITLE').SCORE.sum().sort_values(ascending = False).head(20)
# Out:
# TITLE
# David Attenborough: A Life on Our Planet    9.0
# Inception                                   8.8
# Forrest Gump                                8.8
# Bo Burnham: Inside                          8.7
# Saving Private Ryan                         8.6
# Dangal                                      8.4
# Django Unchained                            8.4
# Dave Chappelle: Sticks & Stones             8.4
# 3 Idiots                                    8.4
# Like Stars on Earth                         8.3
# Once Upon a Time in America                 8.3
# Taxi Driver                                 8.3
# Full Metal Jacket                           8.3
# Bāhubali 2: The Conclusion                  8.2
# Andhadhun                                   8.2
# Queen                                       8.2
# Warrior                                     8.2
# Drishyam                                    8.2
# Monty Python and the Holy Grail             8.2
# ...

# %%
data.groupby('TITLE').SCORE.sum().sort_values(ascending = True).head(20)
# Out:
# TITLE
# The Blue Lagoon            5.8
# Annie                      6.6
# Christine                  6.7
# My Girl                    6.9
# Happy Gilmore              7.0
# Desperado                  7.1
# A River Runs Through It    7.2
# The Tinder Swindler        7.2
# The Patriot                7.2
# Girl, Interrupted          7.3
# Memoirs of a Geisha        7.3
# White Christmas            7.5
# The Guns of Navarone       7.5
# Menace II Society          7.5
# When Harry Met Sally...    7.7
# Road to Perdition          7.7
# Dirty Harry                7.7
# Bonnie and Clyde           7.7
# Awakenings                 7.8
# My Fair Lady               7.8
# Name: SCORE, dtype: float64

# %%
data.head(2)
# Out:
#    index                 TITLE  RELEASE_YEAR  SCORE MAIN_GENRE MAIN_PRODUCTION
# 0      0       White Christmas          1954    7.5    romance              US
# 1      1  The Guns of Navarone          1961    7.5        war              US

# %%
data[data.TITLE == 'Annie']
# Out:
#     index  TITLE  RELEASE_YEAR  SCORE MAIN_GENRE MAIN_PRODUCTION
# 10     10  Annie          1982    6.6      drama              US

# %%
data[data.TITLE == 'Awakenings']
# Out:
#     index       TITLE  RELEASE_YEAR  SCORE MAIN_GENRE MAIN_PRODUCTION
# 16     16  Awakenings          1990    7.8      drama              US

# %%
data[data.TITLE == 'The Tinder Swindler']
# Out:
#     index                TITLE  RELEASE_YEAR  SCORE MAIN_GENRE MAIN_PRODUCTION
# 48     48  The Tinder Swindler          2022    7.2      crime              GB

# %%
data[data.TITLE == 'Memoirs of a Geisha']
# Out:
#     index                TITLE  RELEASE_YEAR  SCORE MAIN_GENRE MAIN_PRODUCTION
# 31     31  Memoirs of a Geisha          2005    7.3      drama              FR

# %%
data.sort_values(by = ['SCORE'])
# Out:
#     index                                           TITLE  RELEASE_YEAR  \
# 9       9                                 The Blue Lagoon          1980
# 10     10                                           Annie          1982
# 11     11                                       Christine          1983
# 17     17                                         My Girl          1991
# 22     22                                   Happy Gilmore          1996
# 21     21                                       Desperado          1995
# 48     48                             The Tinder Swindler          2022
# 26     26                                     The Patriot          2000
# 18     18                         A River Runs Through It          1992
# 31     31                             Memoirs of a Geisha          2005
# 25     25                               Girl, Interrupted          1999
# 19     19                               Menace II Society          1993
# ...

# %%
data.sort_values( by = ['RELEASE_YEAR'] , ascending = False ).head(50)
# Out:
#     index                                           TITLE  RELEASE_YEAR  \
# 48     48                             The Tinder Swindler          2022
# 47     47                              Bo Burnham: Inside          2021
# 46     46        David Attenborough: A Life on Our Planet          2020
# 45     45                 Dave Chappelle: Sticks & Stones          2019
# 44     44                                       Andhadhun          2018
# 43     43                      Bāhubali 2: The Conclusion          2017
# 42     42                                          Dangal          2016
# 41     41                                        Drishyam          2015
# 40     40                                           Queen          2014
# 39     39                                            Rush          2013
# 38     38                                Django Unchained          2012
# 37     37                                         Warrior          2011
# ...
